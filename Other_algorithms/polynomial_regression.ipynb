# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from matplotlib.pyplot import *


data = pd.read_csv(r"/home/madnerd/TheMiners_github/TheMiners/MergedDataFrankfurtDresden.csv", encoding= 'unicode_escape', sep=',', header=0, decimal = ",")
data.head()
# Out:
#      Stadt  Jahr         Wahlart  Kolumna1          Stadtteil zus.  \
# 0  Dresden  2017  Bundestagswahl       NaN      01 Innere Altstadt
# 1  Dresden  2017  Bundestagswahl       NaN      01 Innere Altstadt
# 2  Dresden  2017  Bundestagswahl       NaN  02 Pirnaische Vorstadt
# 3  Dresden  2017  Bundestagswahl       NaN  02 Pirnaische Vorstadt
# 4  Dresden  2017  Bundestagswahl       NaN  02 Pirnaische Vorstadt
#
#    Wahlberechtigte  Wahlberechtigte mit WS  Whler  Whler mit WS  \
# 0                0                       0     411            411
# 1             1328                     422     642              0
# 2                0                       0     694            694
# 3                0                       0     424            424
# 4             1433                     346     691              0
#
#    Stimmen gltig  Stimmen CDU  Stimmen SPD  Stimmen Die Linke  Stimmen Grne  \
# 0             410          110           51                 81             44
# 1             637          134           73                141             44
# 2             690          213           85                125             45
# 3             422          110           67                 87             33
# 4             684          130           84                173             62
#
#    Stimmen FDP  Stimmen AfD  Stimmen Piraten  Stimmen ungltig
# 0           51           51                0                 1
# 1          100          108                0                 5
# 2           63           94                4                 4
# 3           40           49                3                 2
# 4           40          124                8                 7

# %%
x= data.loc[:, 'Stimmen CDU':'Stimmen Piraten']
y= data.iloc[:,[5]]
                
scale = StandardScaler()
x =  scale.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state = 0)
poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x_train)
poly.fit(x_train, y_train)
                
model = LinearRegression()
model.fit(x_poly, y_train)


y_pred = model.predict(poly.fit_transform(x_test))

# %%
print(y_pred)
# Out:
# [[-6.57828336e+03]
#  [ 1.50499061e+03]
#  [ 1.12480541e+03]
#  [ 1.27859177e+03]
#  [ 1.02195304e+03]
#  [ 1.06395928e+03]
#  [-5.54767807e+01]
#  [ 2.47240708e+03]
#  [ 8.79101012e+02]
#  [ 1.18263303e+03]
#  [ 9.58417160e+02]
#  [ 1.05861733e+03]
#  [ 1.13207153e+03]
#  [ 7.50486037e+02]
#  [ 7.07844183e+02]
#  [ 6.70233844e+02]
#  [ 7.22702846e+02]
#  [ 9.15546365e+02]
#  [ 1.29488116e+03]
#  [ 9.57915274e+02]
#  [ 1.15725844e+03]
#  [ 1.54938929e+04]
#  [ 1.32435541e+03]
#  [ 1.02787929e+03]
#  [ 1.57985957e+02]
#  [ 8.47086547e+02]
#  [ 9.97662003e+02]
#  [ 6.34088414e+02]
#  [ 1.59486495e+02]
#  [ 9.84636489e+02]
#  [ 1.04540689e+03]
#  [ 3.22614695e+04]
#  [ 4.24533168e+02]
#  [ 1.31547434e+03]
#  [ 1.49324800e+03]
#  [-1.80528909e+02]
#  [ 1.26575605e+03]
#  [ 6.96346753e+02]
#  [ 1.64722912e+03]
#  [ 4.27828413e+02]
#  [ 9.90126249e+02]
#  [ 1.73048207e+03]
#  [ 1.58450683e+03]
#  [ 5.47965905e+02]
#  [ 2.75915903e+02]
#  [ 1.00189036e+03]
#  [ 1.94323268e+02]
#  [ 9.38575827e+02]
#  [ 1.59930647e+03]
#  [ 3.94590299e+02]
#  [ 5.22329545e+02]
#  [ 1.18178698e+03]
#  [ 1.30513991e+03]
#  [ 2.49126684e+05]
#  [ 1.00463795e+03]
#  [ 1.17138644e+03]
#  [ 1.19905233e+03]
#  [ 7.64512649e+02]
#  [ 1.08495445e+03]
#  [ 1.65228537e+03]
#  [-3.14320136e+05]
#  [ 3.36723511e+02]
#  [ 1.69783992e+03]
#  [ 1.52637581e+03]
#  [ 1.28796572e+03]
#  [ 8.77688703e+02]
#  [ 6.05186482e+02]
#  [ 7.01444330e+02]
#  [ 8.23945592e+01]
#  [ 8.88786497e+02]
#  [ 7.90108724e+02]
#  [ 9.82317152e+02]
#  [ 1.48811591e+03]
#  [ 1.99323290e+02]
#  [ 1.23976978e+03]
#  [-2.90272400e+02]
#  [ 8.16962158e+02]
#  [ 1.38812656e+03]
#  [-2.49192430e+04]
#  [ 4.35009276e+02]
#  [ 8.95735385e+02]
#  [ 1.49764630e+03]
#  [ 7.42101514e+02]
#  [ 8.87816214e+02]
#  [ 1.47535542e+03]
#  [ 6.38740797e+02]
#  [ 1.35287472e+03]
#  [ 1.79444749e+03]
#  [ 1.83785707e+03]
#  [ 1.82284782e+03]
#  [ 9.35562913e+01]
#  [ 5.15736794e+02]
#  [ 8.55664923e+02]
#  [ 9.05402908e+02]
#  [ 9.95998207e+02]
#  [ 1.18021589e+03]
#  [ 1.26189448e+03]
#  [ 6.14296365e+02]
#  [ 7.63013597e+02]
#  [ 1.01879282e+03]
#  [ 1.33712273e+02]
#  [-3.60226484e+02]
#  [ 8.36616850e+02]
#  [ 1.39408163e+03]
#  [ 6.21494563e+01]]

# %%
print(y_test)
# Out:
#      Wahlberechtigte
# 509             6035
# 15              1151
# 456             1394
# 137             1303
# 395              880
# ..               ...
# 455              877
# 206                0
# 357             1121
# 363             1577
# 171             1449
#
# [105 rows x 1 columns]

# %%
# %matplotlib inline
plot(x,y, 'o')
show()
